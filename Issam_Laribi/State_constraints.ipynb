# %% [markdown]
# **State constraints:**
# - No vertex conflicts: two robots cannot occupy the same cell at the same time
# - No edge conflicts: two robots cannot swap positions, i.e. t -> t + 1: r1 goes from position u to position v and r2 goes from position v to position u
# - Path validity: all position in planned path must be walkable
