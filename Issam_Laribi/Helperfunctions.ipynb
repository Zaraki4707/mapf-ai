# %%
def SetTask(Robots : list, GridEnvironment):
    """
        This function creates tasks to the given robots, i.e. it sets starting positions and goal positions to the given robots
        It ensures the soundness of the starting positions and the goal positions for all robots
        It will be helpful during the testing phase

        Arguments:
            Robots: a list of robots
            GridEnvironment: the grid those robots will do their task in 
        Output: 
            Setting the positions to each robot -> Void
    """
    pass

# %%
def function():
    """
    """
    pass
